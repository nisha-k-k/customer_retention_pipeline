# %% [markdown]
# ## Customer Retention Pipeline

# %% [markdown]
# ## Create Tables

# %%
import pandas as pd

# %%
df = pd.read_csv('data/customers.csv')

df.head()
# Out:
#    customer_id            name                        email  age gender  \
# 0            1   Mary Anderson  jameswhite@silva-reese.info   58   Male
# 1            2  Matthew Greene      keithjane@rodriguez.com   35   Male
# 2            3    Sarah Sparks      sullivanjoshua@pugh.com   65   Male
# 3            4    Levi Meadows        brockandrea@gmail.com   75  Other
# 4            5     Jared Garza     gutierrezdavid@yahoo.com   45   Male
#
#               city state signup_date last_purchase_date customer_tier
# 0      North Ruben    IN  2020-11-08         2021-07-20        Bronze
# 1      Michaelstad    CO  2021-04-17         2024-08-27        Bronze
# 2  Jonathanchester    AZ  2020-11-13         2022-01-25        Silver
# 3       Rogermouth    KY  2024-12-01         2025-04-16        Bronze
# 4   Matthewchester    OH  2025-02-16         2025-03-22        Bronze
